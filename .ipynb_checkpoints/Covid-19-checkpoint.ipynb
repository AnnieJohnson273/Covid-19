# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv("AgeGroupDetails.csv")
d2=pd.read_csv("covid_19_india.csv")
d3=pd.read_csv("HospitalBedsIndia.csv")
d4=pd.read_csv("ICMRTestingDetails.csv")
d5=pd.read_csv("ICMRTestingLabs.csv")
d6=pd.read_csv("IndividualDetails.csv")
d7=pd.read_csv("StatewiseTestingDetails.csv")
d8=pd.read_csv("population_india_census2011.csv")

# %%
d1.describe()
# Out:
#             Sno  TotalCases
# count  10.00000   10.000000
# mean    5.50000   69.200000
# std     3.02765   59.241127
# min     1.00000    9.000000
# 25%     3.25000   23.250000
# 50%     5.50000   52.500000
# 75%     7.75000  106.250000
# max    10.00000  172.000000

# %%
plt.plot(d1.Sno,d1.TotalCases)
plt.show()

# %%
plt.scatter(d1.Sno,d1.TotalCases,color='purple')
plt.show()

# %%
plt.bar(d1.Sno,d1.TotalCases,color='brown')
plt.show()

# %%
d2.describe()
# Out:
#                Sno        Cured       Deaths     Confirmed
# count  1510.000000  1510.000000  1510.000000   1510.000000
# mean    755.500000    56.500662     9.684768    309.396689
# std     436.043767   166.717714    36.363801    862.996336
# min       1.000000     0.000000     0.000000      0.000000
# 25%     378.250000     0.000000     0.000000      4.000000
# 50%     755.500000     3.000000     0.000000     27.000000
# 75%    1132.750000    25.000000     3.000000    199.000000
# max    1510.000000  1773.000000   459.000000  10498.000000

# %%
d2.tail()
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1505  1506  01/05/20  5:00 PM            Telengana                       -
# 1506  1507  01/05/20  5:00 PM              Tripura                       -
# 1507  1508  01/05/20  5:00 PM          Uttarakhand                       -
# 1508  1509  01/05/20  5:00 PM        Uttar Pradesh                       -
# 1509  1510  01/05/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 1505                        -    441      26       1039
# 1506                        -      2       0          2
# 1507                        -     36       0         57
# 1508                        -    555      41       2281
# 1509                        -    139      33        795

# %%
plt.plot(d2.Cured,d2.Deaths,color='pink')

# %%
plt.scatter(d2.Cured,d2.Deaths,color='y')
plt.show()

# %%
plt.bar(d2.Cured,d2.Deaths,color='pink',width=8)
plt.show()

# %%
d3.describe()
# Out:
#              Sno  NumCommunityHealthCenters_HMIS  \
# count  37.000000                       37.000000
# mean   19.000000                      300.972973
# std    10.824355                      907.160512
# min     1.000000                        2.000000
# 25%    10.000000                       17.000000
# 50%    19.000000                       82.000000
# 75%    28.000000                      229.000000
# max    37.000000                     5568.000000
#
#        NumSubDistrictHospitals_HMIS  NumDistrictHospitals_HMIS  \
# count                     30.000000                  37.000000
# mean                      83.666667                  54.216216
# std                      229.572817                 163.173584
# min                        1.000000                   1.000000
# 25%                        6.000000                   9.000000
# 50%                       25.500000                  23.000000
# 75%                       63.250000                  37.000000
# ...

# %%
d4.describe()
# Out:
#              SNo  TotalSamplesTested  TotalIndividualsTested  \
# count  42.000000           38.000000               23.000000
# mean   21.500000       207110.631579           185311.695652
# std    12.267844       213570.384020           170736.199794
# min     1.000000         6500.000000             5900.000000
# 25%    11.250000        30376.500000            18527.000000
# 50%    21.500000       120967.000000           164773.000000
# 75%    31.750000       327081.250000           302581.500000
# max    42.000000       716733.000000           525667.000000
#
#        TotalPositiveCases
# count           31.000000
# mean          6322.870968
# std           6720.816452
# min             78.000000
# 25%            558.500000
# 50%           4135.000000
# 75%           9824.000000
# max          23502.000000

# %%
d4.head()
# Out:
#    SNo        DateTime  TotalSamplesTested  TotalIndividualsTested  \
# 0    1  13/03/20 18:00              6500.0                  5900.0
# 1    2  18/03/20 18:00             13125.0                 12235.0
# 2    3  19/03/20 18:00             14175.0                 13285.0
# 3    4  20/03/20 18:00             15404.0                 14514.0
# 4    5  21/03/20 18:00             16911.0                 16021.0
#
#    TotalPositiveCases
# 0                78.0
# 1               150.0
# 2               182.0
# 3               236.0
# 4               315.0

# %%
d5.head()
# Out:
#                                                  lab  \
# 0  ICMR-Regional Medical Research Centre, Port Blair
# 1  Tomo Riba Institute of Health & Medical Scienc...
# 2  Sri Venkateswara Institute of Medical Sciences...
# 3                Rangaraya Medical College, Kakinada
# 4               Sidhartha Medical College, Vijaywada
#
#                                              address  pincode        city  \
# 0  ICMR-Regional Medical Research Centre, Post Ba...   744103  Port Blair
# 1  National Highway 52A, Old Assembly Complex, Na...   791110  Naharlagun
# 2  Sri Venkateswara Institute of Medical Sciences...   517507    Tirupati
# 3  Rangaraya Medical College, Kakinada Pithampura...   533001    Kakinada
# 4  Siddhartha Medical College, Vijayawada NH 16 S...   520008  Vijayawada
#
#                          state                   type
# 0  Andaman and Nicobar Islands  Government Laboratory
# 1            Arunachal Pradesh        Collection Site
# ...

# %%
d6.describe()
# Out:
#                  id
# count  27890.000000
# mean   13945.343134
# std     8051.522929
# min        0.000000
# 25%     6973.250000
# 50%    13945.500000
# 75%    20917.750000
# max    27890.000000

# %%
d5.describe()
# Out:
#              pincode
# count     267.000000
# mean   457908.602996
# std    211021.221804
# min    110001.000000
# 25%    303511.500000
# 50%    462030.000000
# 75%    622510.500000
# max    846003.000000

# %%
d6.tail(n=7)
# Out:
#           id government_id diagnosed_date  age gender detected_city  \
# 27883  27884           NaN     26/04/2020  NaN    NaN           NaN
# 27884  27885           NaN     26/04/2020  NaN    NaN           NaN
# 27885  27886           NaN     26/04/2020  NaN    NaN           NaN
# 27886  27887           NaN     26/04/2020  NaN    NaN           NaN
# 27887  27888           NaN     26/04/2020   12      F           NaN
# 27888  27889           NaN     26/04/2020   13      F           NaN
# 27889  27890           NaN     26/04/2020   17      F           NaN
#
#       detected_district detected_state nationality current_status  \
# 27883               NaN          Delhi         NaN   Hospitalized
# 27884               NaN          Delhi         NaN   Hospitalized
# 27885               NaN          Delhi         NaN   Hospitalized
# 27886               NaN    Uttarakhand         NaN   Hospitalized
# 27887            Munger          Bihar         NaN   Hospitalized
# ...

# %%
d7.describe()
# Out:
#         TotalSamples       Negative     Positive
# count     556.000000     464.000000   549.000000
# mean    15160.609712   15139.693966   575.462659
# std     20414.193642   19980.628391  1038.960405
# min        58.000000       0.000000     0.000000
# 25%      2010.000000    2329.500000    32.000000
# 50%      7211.000000    7162.000000   193.000000
# 75%     19389.750000   19363.000000   572.000000
# max    120620.000000  112552.000000  8590.000000

# %%
plt.plot(d7.TotalSamples,d7.Positive,color='red')
plt.show()

# %%
d8.describe()
# Out:
#              Sno    Population  Rural population  Urban population  \
# count  36.000000  3.600000e+01      3.600000e+01      3.600000e+01
# mean   18.500000  3.362689e+07      2.315336e+07      1.047353e+07
# std    10.535654  4.305758e+07      3.212429e+07      1.312631e+07
# min     1.000000  6.447300e+04      1.414100e+04      5.033200e+04
# 25%     9.750000  1.439840e+06      5.451570e+05      6.652765e+05
# 50%    18.500000  2.106970e+07      1.278679e+07      5.167890e+06
# 75%    27.250000  5.229275e+07      3.496766e+07      1.604342e+07
# max    36.000000  1.998123e+08      1.553173e+08      5.081826e+07
#
#        Gender Ratio
# count     36.000000
# mean     937.583333
# std       65.544478
# min      711.000000
# 25%      907.750000
# 50%      947.000000
# 75%      976.750000
# max     1084.000000

# %%
d8.head(n=7)
# Out:
#    Sno State / Union Territory  Population  Rural population  \
# 0    1           Uttar Pradesh   199812341         155317278
# 1    2             Maharashtra   112374333          61556074
# 2    3                   Bihar   104099452          92341436
# 3    4             West Bengal    91276115          62183113
# 4    5          Madhya Pradesh    72626809          52557404
# 5    6              Tamil Nadu    72147030          37229590
# 6    7               Rajasthan    68548437          51500352
#
#    Urban population                         Area                  Density  \
# 0          44495063   240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)
# 1          50818259  307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)
# 2          11758016    94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)
# 3          29093002    88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)
# 4          20069405  308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)
# ...
